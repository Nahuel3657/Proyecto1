# %% [markdown]
# # evaluacion otros dias

# %% [markdown]
# # 01 de enero de 2023

# %%
import pandas as pd
import numpy as np

# %%
dataPrueba1 = pd.read_csv('01 de enero 2023.csv')

# %%
dataPrueba1.head()
# Out:
#           01/01/2023           H1           H2           H3          H4  \
# 0               REAL  1149.850000  1069.360000  1005.650000  967.860000
# 1    PROPHET_Domingo  1074.229469  1018.523656   980.973462  952.379697
# 2      ARIMA_Domingo  1062.484207  1008.362265   969.143376  946.707704
# 3  PROPHET_TodosDias  1089.683868  1086.939045   982.647621  953.654213
# 4    ARIMA_TodosDias  1082.865457  1029.878105   992.768773  950.746046
#
#            H5          H6          H7           H8           H9  ...  \
# 0  942.660000  832.495500  810.763000   835.511000   882.730000  ...
# 1  939.963370  853.997129  838.984606   903.966111   975.402121  ...
# 2  899.670701  849.384674  824.628977   907.433009   963.801012  ...
# 3  953.390684  843.173877  862.795408   916.909957   966.634127  ...
# 4  959.644263  872.311654  919.117898  1031.723599  1135.113263  ...
#
#            H15          H16          H17          H18          H19  \
# ...

# %%
dataPrueba01 = dataPrueba1.set_index('01/01/2023')
dataPrueba01
# Out:
#                             H1           H2           H3          H4  \
# 01/01/2023
# REAL               1149.850000  1069.360000  1005.650000  967.860000
# PROPHET_Domingo    1074.229469  1018.523656   980.973462  952.379697
# ARIMA_Domingo      1062.484207  1008.362265   969.143376  946.707704
# PROPHET_TodosDias  1089.683868  1086.939045   982.647621  953.654213
# ARIMA_TodosDias    1082.865457  1029.878105   992.768773  950.746046
# CNDC_Predic        1066.280000   971.660000   898.420000  854.860000
#
#                            H5          H6          H7           H8  \
# 01/01/2023
# REAL               942.660000  832.495500  810.763000   835.511000
# PROPHET_Domingo    939.963370  853.997129  838.984606   903.966111
# ARIMA_Domingo      899.670701  849.384674  824.628977   907.433009
# PROPHET_TodosDias  953.390684  843.173877  862.795408   916.909957
# ARIMA_TodosDias    959.644263  872.311654  919.117898  1031.723599
# ...

# %%
#dataPrueba_1 = dataPrueba01.drop(columns=["TOTAL","DEMANDA MAXIMA"])

# %%
# invertir columnas y filas
dataPrueba1inv = dataPrueba01.transpose()
dataPrueba1inv
# Out:
# 01/01/2023       REAL  PROPHET_Domingo  ARIMA_Domingo  PROPHET_TodosDias  \
# H1          1149.8500      1074.229469    1062.484207        1089.683868
# H2          1069.3600      1018.523656    1008.362265        1086.939045
# H3          1005.6500       980.973462     969.143376         982.647621
# H4           967.8600       952.379697     946.707704         953.654213
# H5           942.6600       939.963370     899.670701         953.390684
# H6           832.4955       853.997129     849.384674         843.173877
# H7           810.7630       838.984606     824.628977         862.795408
# H8           835.5110       903.966111     907.433009         916.909957
# H9           882.7300       975.402121     963.801012         966.634127
# H10          941.5490      1024.239214    1007.289502        1029.029949
# H11          991.4760      1057.600092    1037.700951        1059.599520
# H12         1020.3860      1081.933555    1021.571283        1077.528761
# ...

# %%
# Evaluacion del modelo PROPHET que predijo usando dias especifico DOMINGO
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of PROPHET_Lunes:", mean_squared_error(dataPrueba1inv['REAL'],dataPrueba1inv['PROPHET_Domingo']))
print("RMSE of PROPHET_Lunes:", np.sqrt(mean_squared_error(dataPrueba1inv['REAL'],dataPrueba1inv['PROPHET_Domingo'])))
print("MAE of PROPHET_Lunest:", mean_absolute_error(dataPrueba1inv['REAL'],dataPrueba1inv['PROPHET_Domingo']))
print("MAPE of PROPHET_Lunes:", mean_absolute_percentage_error(dataPrueba1inv['REAL'],dataPrueba1inv['PROPHET_Domingo']))
print("R2 of PROPHET_Lunes:", r2_score(dataPrueba1inv['REAL'],dataPrueba1inv['PROPHET_Domingo']))
# Out:
# MSE of PROPHET_Lunes: 3025.3338359462746
# RMSE of PROPHET_Lunes: 55.00303478851212
# MAE of PROPHET_Lunest: 49.810058416666664
# MAPE of PROPHET_Lunes: 0.04762088295446577
# R2 of PROPHET_Lunes: 0.8377314202626379

# %%
# Evaluacion del modelo ARIMA que predijo usando dias especifico DOMINGO
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of ARIMA_Lunes:", mean_squared_error(dataPrueba1inv['REAL'],dataPrueba1inv['ARIMA_Domingo']))
print("RMSE of ARIMA_Lunes:", np.sqrt(mean_squared_error(dataPrueba1inv['REAL'],dataPrueba1inv['ARIMA_Domingo'])))
print("MAE of ARIMA_Lunes:", mean_absolute_error(dataPrueba1inv['REAL'],dataPrueba1inv['ARIMA_Domingo']))
print("MAPE of ARIMA_Lunes:", mean_absolute_percentage_error(dataPrueba1inv['REAL'],dataPrueba1inv['ARIMA_Domingo']))
print("R2 of ARIMA_Lunes:", r2_score(dataPrueba1inv['REAL'],dataPrueba1inv['ARIMA_Domingo']))
# Out:
# MSE of ARIMA_Lunes: 1670.370479384259
# RMSE of ARIMA_Lunes: 40.870166128659896
# MAE of ARIMA_Lunes: 30.863311875000004
# MAPE of ARIMA_Lunes: 0.03100991843921783
# R2 of ARIMA_Lunes: 0.9104070294311435

# %%
# Evaluacion del modelo PROPHET que predijo usando todos los dias
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of PROPHET_TodosDias:", mean_squared_error(dataPrueba1inv['REAL'],dataPrueba1inv['PROPHET_TodosDias']))
print("RMSE of PROPHET_TodosDias:", np.sqrt(mean_squared_error(dataPrueba1inv['REAL'],dataPrueba1inv['PROPHET_TodosDias'])))
print("MAE of PROPHET_TodosDias:", mean_absolute_error(dataPrueba1inv['REAL'],dataPrueba1inv['PROPHET_TodosDias']))
print("MAPE of PROPHET_TodosDias:", mean_absolute_percentage_error(dataPrueba1inv['REAL'],dataPrueba1inv['PROPHET_TodosDias']))
print("R2 of PROPHET_TodosDias:", r2_score(dataPrueba1inv['REAL'],dataPrueba1inv['PROPHET_TodosDias']))
# Out:
# MSE of PROPHET_TodosDias: 3258.857901811992
# RMSE of PROPHET_TodosDias: 57.0864073296962
# MAE of PROPHET_TodosDias: 49.88063133333335
# MAPE of PROPHET_TodosDias: 0.048104239171879344
# R2 of PROPHET_TodosDias: 0.8252059865229687

# %%
# Evaluacion del modelo ARIMA que predijo usando todos los dias
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of ARIMA_TodosDias:", mean_squared_error(dataPrueba1inv['REAL'],dataPrueba1inv['ARIMA_TodosDias']))
print("RMSE of ARIMA_TodosDias:", np.sqrt(mean_squared_error(dataPrueba1inv['REAL'],dataPrueba1inv['ARIMA_TodosDias'])))
print("MAE of ARIMA_TodosDias:", mean_absolute_error(dataPrueba1inv['REAL'],dataPrueba1inv['ARIMA_TodosDias']))
print("MAPE of ARIMA_TodosDias:", mean_absolute_percentage_error(dataPrueba1inv['REAL'],dataPrueba1inv['ARIMA_TodosDias']))
print("R2 of ARIMA_TodosDias:", r2_score(dataPrueba1inv['REAL'],dataPrueba1inv['ARIMA_TodosDias']))
# Out:
# MSE of ARIMA_TodosDias: 37957.610747460254
# RMSE of ARIMA_TodosDias: 194.82713041940605
# MAE of ARIMA_TodosDias: 170.67877887499995
# MAPE of ARIMA_TodosDias: 0.16395537087119275
# R2 of ARIMA_TodosDias: -1.0359166691061952

# %%
# Evaluacion de la prediccion del CNDC
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

#print("MSE of PROPHET_Lunes:", mean_squared_error(dataPrueba1inv['REAL'],dataPrueba1inv['CNDC_Predic']))
print("RMSE of PROPHET_Lunes:", np.sqrt(mean_squared_error(dataPrueba1inv['REAL'],dataPrueba1inv['CNDC_Predic'])))
print("MAE of PROPHET_Lunest:", mean_absolute_error(dataPrueba1inv['REAL'],dataPrueba1inv['CNDC_Predic']))
print("MAPE of PROPHET_Lunes:", mean_absolute_percentage_error(dataPrueba1inv['REAL'],dataPrueba1inv['CNDC_Predic']))
print("R2 of PROPHET_Lunes:", r2_score(dataPrueba1inv['REAL'],dataPrueba1inv['CNDC_Predic']))
# Out:
# RMSE of PROPHET_Lunes: 95.88534297627078
# MAE of PROPHET_Lunest: 94.58272916666664
# MAPE of PROPHET_Lunes: 0.09215505438419956
# R2 of PROPHET_Lunes: 0.5068652782270061

# %%
# exportar a csv
#dataPrueba1inv.to_csv('01enero2023.csv')# exportar a csv

# %% [markdown]
# # 02 de enero de 2023

# %%
dataPrueba2 = pd.read_csv('02 de enero 2023.csv')

# %%
dataPrueba2.head()
# Out:
#           02/01/2023           H1           H2           H3           H4  \
# 0               REAL  1024.410000   963.780000   928.090000   899.610000
# 1      PROPHET_Lunes   997.176982   938.587162   909.653092   893.344412
# 2        ARIMA_Lunes   950.173923   892.783150   870.550458   878.907091
# 3  PROPHET_TodosDias  1038.044102   987.086101   955.129833   993.694556
# 4    ARIMA_TodosDias  1117.709462  1062.701392  1026.426255  1001.300208
#
#             H5          H6           H7           H8           H9  ...  \
# 0   897.030000  830.520000   834.592000   886.622000   962.326000  ...
# 1   907.196613  874.351865   928.274322  1017.923628  1101.574226  ...
# 2   869.964752  857.498835   891.786794   951.692740  1065.104512  ...
# 3   950.309714  889.503413  1039.763979  1123.262883  1227.849998  ...
# 4  1022.755655  955.967148  1067.498590  1206.993137  1343.962763  ...
#
#            H17          H18          H19          H20          H21  \
# ...

# %%
dataPrueba02 = dataPrueba2.set_index('02/01/2023')
dataPrueba02
# Out:
#                             H1           H2           H3           H4  \
# 02/01/2023
# REAL               1024.410000   963.780000   928.090000   899.610000
# PROPHET_Lunes       997.176982   938.587162   909.653092   893.344412
# ARIMA_Lunes         950.173923   892.783150   870.550458   878.907091
# PROPHET_TodosDias  1038.044102   987.086101   955.129833   993.694556
# ARIMA_TodosDias    1117.709462  1062.701392  1026.426255  1001.300208
# CNDC_Predic         959.640000   905.770000   870.630000   847.440000
#
#                             H5          H6           H7           H8  \
# 02/01/2023
# REAL                897.030000  830.520000   834.592000   886.622000
# PROPHET_Lunes       907.196613  874.351865   928.274322  1017.923628
# ARIMA_Lunes         869.964752  857.498835   891.786794   951.692740
# PROPHET_TodosDias   950.309714  889.503413  1039.763979  1123.262883
# ARIMA_TodosDias    1022.755655  955.967148  1067.498590  1206.993137
# ...

# %%
dataPrueba_2 = dataPrueba02.drop(columns=["TOTAL","DEMANDA MAXIMA"])

# %%
# invertir columnas y filas
dataPrueba2inv = dataPrueba_2.transpose()
dataPrueba2inv
# Out:
# 02/01/2023      REAL  PROPHET_Lunes  ARIMA_Lunes  PROPHET_TodosDias  \
# H1          1024.410     997.176982   950.173923        1038.044102
# H2           963.780     938.587162   892.783150         987.086101
# H3           928.090     909.653092   870.550458         955.129833
# H4           899.610     893.344412   878.907091         993.694556
# H5           897.030     907.196613   869.964752         950.309714
# H6           830.520     874.351865   857.498835         889.503413
# H7           834.592     928.274322   891.786794        1039.763979
# H8           886.622    1017.923628   951.692740        1123.262883
# H9           962.326    1101.574226  1065.104512        1227.849998
# H10         1018.745    1166.828666  1136.751562        1284.431629
# H11         1066.459    1208.026364  1201.695345        1327.334454
# H12         1098.047    1213.052017  1228.105458        1351.475038
# H13         1095.101    1195.843630  1216.795598        1331.820722
# ...

# %%
# Evaluacion del modelo PROPHET que predijo usando dias especifico LUNES
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of PROPHET_Lunes:", mean_squared_error(dataPrueba2inv['REAL'],dataPrueba2inv['PROPHET_Lunes']))
print("RMSE of PROPHET_Lunes:", np.sqrt(mean_squared_error(dataPrueba2inv['REAL'],dataPrueba2inv['PROPHET_Lunes'])))
print("MAE of PROPHET_Lunest:", mean_absolute_error(dataPrueba2inv['REAL'],dataPrueba2inv['PROPHET_Lunes']))
print("MAPE of PROPHET_Lunes:", mean_absolute_percentage_error(dataPrueba2inv['REAL'],dataPrueba2inv['PROPHET_Lunes']))
print("R2 of PROPHET_Lunes:", r2_score(dataPrueba2inv['REAL'],dataPrueba2inv['PROPHET_Lunes']))
# Out:
# MSE of PROPHET_Lunes: 10886.176032535846
# RMSE of PROPHET_Lunes: 104.33683928764493
# MAE of PROPHET_Lunest: 88.8301670416667
# MAPE of PROPHET_Lunes: 0.08483399690006367
# R2 of PROPHET_Lunes: 0.43586902374493397

# %%
# Evaluacion del modelo ARIMA que predijo usando dias especifico LUNES
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of ARIMA_Lunes:", mean_squared_error(dataPrueba2inv['REAL'],dataPrueba2inv['ARIMA_Lunes']))
print("RMSE of ARIMA_Lunes:", np.sqrt(mean_squared_error(dataPrueba2inv['REAL'],dataPrueba2inv['ARIMA_Lunes'])))
print("MAE of ARIMA_Lunes:", mean_absolute_error(dataPrueba2inv['REAL'],dataPrueba2inv['ARIMA_Lunes']))
print("MAPE of ARIMA_Lunes:", mean_absolute_percentage_error(dataPrueba2inv['REAL'],dataPrueba2inv['ARIMA_Lunes']))
print("R2 of ARIMA_Lunes:", r2_score(dataPrueba2inv['REAL'],dataPrueba2inv['ARIMA_Lunes']))
# Out:
# MSE of ARIMA_Lunes: 14338.213898368907
# RMSE of ARIMA_Lunes: 119.74228116404376
# MAE of ARIMA_Lunes: 105.12854533333335
# MAPE of ARIMA_Lunes: 0.09831780779209269
# R2 of ARIMA_Lunes: 0.25698146162012525

# %%
# Evaluacion del modelo PROPHET que predijo usando todos los dias
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of PROPHET_TodosDias:", mean_squared_error(dataPrueba2inv['REAL'],dataPrueba2inv['PROPHET_TodosDias']))
print("RMSE of PROPHET_TodosDias:", np.sqrt(mean_squared_error(dataPrueba2inv['REAL'],dataPrueba2inv['PROPHET_TodosDias'])))
print("MAE of PROPHET_TodosDias:", mean_absolute_error(dataPrueba2inv['REAL'],dataPrueba2inv['PROPHET_TodosDias']))
print("MAPE of PROPHET_TodosDias:", mean_absolute_percentage_error(dataPrueba2inv['REAL'],dataPrueba2inv['PROPHET_TodosDias']))
print("R2 of PROPHET_TodosDias:", r2_score(dataPrueba2inv['REAL'],dataPrueba2inv['PROPHET_TodosDias']))
# Out:
# MSE of PROPHET_TodosDias: 42245.89632854361
# RMSE of PROPHET_TodosDias: 205.53806540041094
# MAE of PROPHET_TodosDias: 181.3489640833333
# MAPE of PROPHET_TodosDias: 0.17207836886755182
# R2 of PROPHET_TodosDias: -1.1892185710908532

# %%
# Evaluacion del modelo ARIMA que predijo usando todos los dias
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of ARIMA_TodosDias:", mean_squared_error(dataPrueba1inv['REAL'],dataPrueba1inv['ARIMA_TodosDias']))
print("RMSE of ARIMA_TodosDias:", np.sqrt(mean_squared_error(dataPrueba1inv['REAL'],dataPrueba1inv['ARIMA_TodosDias'])))
print("MAE of ARIMA_TodosDias:", mean_absolute_error(dataPrueba1inv['REAL'],dataPrueba1inv['ARIMA_TodosDias']))
print("MAPE of ARIMA_TodosDias:", mean_absolute_percentage_error(dataPrueba1inv['REAL'],dataPrueba1inv['ARIMA_TodosDias']))
print("R2 of ARIMA_TodosDias:", r2_score(dataPrueba1inv['REAL'],dataPrueba1inv['ARIMA_TodosDias']))
# Out:
# MSE of ARIMA_TodosDias: 37957.610747460254
# RMSE of ARIMA_TodosDias: 194.82713041940605
# MAE of ARIMA_TodosDias: 170.67877887499995
# MAPE of ARIMA_TodosDias: 0.16395537087119275
# R2 of ARIMA_TodosDias: -1.0359166691061952

# %%
# Evaluacion de la prediccion del CNDC
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of PROPHET_Lunes:", mean_squared_error(dataPrueba2inv['REAL'],dataPrueba2inv['CNDC_Predic']))
print("RMSE of PROPHET_Lunes:", np.sqrt(mean_squared_error(dataPrueba2inv['REAL'],dataPrueba2inv['CNDC_Predic'])))
print("MAE of PROPHET_Lunest:", mean_absolute_error(dataPrueba2inv['REAL'],dataPrueba2inv['CNDC_Predic']))
print("MAPE of PROPHET_Lunes:", mean_absolute_percentage_error(dataPrueba2inv['REAL'],dataPrueba2inv['CNDC_Predic']))
print("R2 of PROPHET_Lunes:", r2_score(dataPrueba2inv['REAL'],dataPrueba2inv['CNDC_Predic']))
# Out:
# MSE of PROPHET_Lunes: 2014.1485613750003
# RMSE of PROPHET_Lunes: 44.87926649773813
# MAE of PROPHET_Lunest: 41.19645833333335
# MAPE of PROPHET_Lunes: 0.041443557795505376
# R2 of PROPHET_Lunes: 0.8956250945368429

# %%
# exportar a csv
#dataPrueba2inv.to_csv('02enero2023.csv')# exportar a csv

# %% [markdown]
# # 03 de enero de 2023

# %%
dataPrueba3 = pd.read_csv('03 de enero 2023.csv')

# %%
dataPrueba3.head()
# Out:
#           03/01/2023           H1           H2           H3           H4  \
# 0               REAL   992.610000   944.100000   914.650000   898.280000
# 1     PROPHET_Martes  1038.626626   979.494143   954.728689   934.640699
# 2       ARIMA_Martes  1070.246439  1004.591529   958.441393   953.579722
# 3  PROPHET_TodosDias  1101.574343  1051.444358  1017.292960  1057.643844
# 4    ARIMA_TodosDias  1170.989628  1111.134719  1060.514945  1039.311261
#
#             H5           H6           H7           H8           H9  ...  \
# 0   909.250000   907.912000   967.444000  1072.211000  1190.475000  ...
# 1   951.741270   917.474018   970.728654  1062.711611  1162.392002  ...
# 2   989.764026   966.802029  1042.367281  1181.802187  1272.443513  ...
# 3  1016.236763  1016.236763  1073.782369  1070.901630  1273.444872  ...
# 4  1052.034142   982.112307  1063.139114  1202.833462  1315.790047  ...
#
#            H17          H18          H19          H20          H21  \
# ...

# %%
dataPrueba03 = dataPrueba3.set_index('03/01/2023')
dataPrueba03
# Out:
#                             H1           H2           H3           H4  \
# 03/01/2023
# REAL                992.610000   944.100000   914.650000   898.280000
# PROPHET_Martes     1038.626626   979.494143   954.728689   934.640699
# ARIMA_Martes       1070.246439  1004.591529   958.441393   953.579722
# PROPHET_TodosDias  1101.574343  1051.444358  1017.292960  1057.643844
# ARIMA_TodosDias    1170.989628  1111.134719  1060.514945  1039.311261
# CNDC_Predic         980.670000   922.520000   891.411000   871.780000
#
#                             H5           H6           H7           H8  \
# 03/01/2023
# REAL                909.250000   907.912000   967.444000  1072.211000
# PROPHET_Martes      951.741270   917.474018   970.728654  1062.711611
# ARIMA_Martes        989.764026   966.802029  1042.367281  1181.802187
# PROPHET_TodosDias  1016.236763  1016.236763  1073.782369  1070.901630
# ARIMA_TodosDias    1052.034142   982.112307  1063.139114  1202.833462
# ...

# %%
dataPrueba_3 = dataPrueba03.drop(columns=["TOTAL","DEMANDA MAXIMA"])

# %%
# invertir columnas y filas
dataPrueba3inv = dataPrueba_3.transpose()
dataPrueba3inv
# Out:
# 03/01/2023      REAL  PROPHET_Martes  ARIMA_Martes  PROPHET_TodosDias  \
# H1           992.610     1038.626626   1070.246439        1101.574343
# H2           944.100      979.494143   1004.591529        1051.444358
# H3           914.650      954.728689    958.441393        1017.292960
# H4           898.280      934.640699    953.579722        1057.643844
# H5           909.250      951.741270    989.764026        1016.236763
# H6           907.912      917.474018    966.802029        1016.236763
# H7           967.444      970.728654   1042.367281        1073.782369
# H8          1072.211     1062.711611   1181.802187        1070.901630
# H9          1190.475     1162.392002   1272.443513        1273.444872
# H10         1228.305     1223.746305   1340.748576        1317.823095
# H11         1285.255     1276.866840   1397.135987        1361.306743
# H12         1271.919     1279.715879   1420.183305        1372.119606
# ...

# %%
# Evaluacion del modelo PROPHET que predijo usando dias especifico MARTES
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of PROPHET_Lunes:", mean_squared_error(dataPrueba3inv['REAL'],dataPrueba3inv['PROPHET_Martes']))
print("RMSE of PROPHET_Lunes:", np.sqrt(mean_squared_error(dataPrueba3inv['REAL'],dataPrueba3inv['PROPHET_Martes'])))
print("MAE of PROPHET_Lunest:", mean_absolute_error(dataPrueba3inv['REAL'],dataPrueba3inv['PROPHET_Martes']))
print("MAPE of PROPHET_Lunes:", mean_absolute_percentage_error(dataPrueba3inv['REAL'],dataPrueba3inv['PROPHET_Martes']))
print("R2 of PROPHET_Lunes:", r2_score(dataPrueba3inv['REAL'],dataPrueba3inv['PROPHET_Martes']))
# Out:
# MSE of PROPHET_Lunes: 794.8726551203553
# RMSE of PROPHET_Lunes: 28.19348604057957
# MAE of PROPHET_Lunest: 23.450415000000007
# MAPE of PROPHET_Lunes: 0.021060702210288964
# R2 of PROPHET_Lunes: 0.9743938909409983

# %%
# Evaluacion del modelo ARIMA que predijo usando dias especifico MARTES
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of ARIMA_Lunes:", mean_squared_error(dataPrueba3inv['REAL'],dataPrueba3inv['ARIMA_Martes']))
print("RMSE of ARIMA_Lunes:", np.sqrt(mean_squared_error(dataPrueba3inv['REAL'],dataPrueba3inv['ARIMA_Martes'])))
print("MAE of ARIMA_Lunes:", mean_absolute_error(dataPrueba3inv['REAL'],dataPrueba3inv['ARIMA_Martes']))
print("MAPE of ARIMA_Lunes:", mean_absolute_percentage_error(dataPrueba3inv['REAL'],dataPrueba3inv['ARIMA_Martes']))
print("R2 of ARIMA_Lunes:", r2_score(dataPrueba3inv['REAL'],dataPrueba3inv['ARIMA_Martes']))
# Out:
# MSE of ARIMA_Lunes: 14862.585703271056
# RMSE of ARIMA_Lunes: 121.91220489873463
# MAE of ARIMA_Lunes: 113.02372287499998
# MAPE of ARIMA_Lunes: 0.09453329935842993
# R2 of ARIMA_Lunes: 0.5212151431236567

# %%
# Evaluacion del modelo PROPHET que predijo usando todos los dias
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of PROPHET_TodosDias:", mean_squared_error(dataPrueba3inv['REAL'],dataPrueba3inv['PROPHET_TodosDias']))
print("RMSE of PROPHET_TodosDias:", np.sqrt(mean_squared_error(dataPrueba3inv['REAL'],dataPrueba3inv['PROPHET_TodosDias'])))
print("MAE of PROPHET_TodosDias:", mean_absolute_error(dataPrueba3inv['REAL'],dataPrueba3inv['PROPHET_TodosDias']))
print("MAPE of PROPHET_TodosDias:", mean_absolute_percentage_error(dataPrueba3inv['REAL'],dataPrueba3inv['PROPHET_TodosDias']))
print("R2 of PROPHET_TodosDias:", r2_score(dataPrueba3inv['REAL'],dataPrueba3inv['PROPHET_TodosDias']))
# Out:
# MSE of PROPHET_TodosDias: 9263.627669532723
# RMSE of PROPHET_TodosDias: 96.2477411139229
# MAE of PROPHET_TodosDias: 90.42418362499996
# MAPE of PROPHET_TodosDias: 0.08070221673772343
# R2 of PROPHET_TodosDias: 0.7015805502176642

# %%
# Evaluacion del modelo ARIMA que predijo usando todos los dias
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of ARIMA_TodosDias:", mean_squared_error(dataPrueba3inv['REAL'],dataPrueba3inv['ARIMA_TodosDias']))
print("RMSE of ARIMA_TodosDias:", np.sqrt(mean_squared_error(dataPrueba3inv['REAL'],dataPrueba3inv['ARIMA_TodosDias'])))
print("MAE of ARIMA_TodosDias:", mean_absolute_error(dataPrueba3inv['REAL'],dataPrueba3inv['ARIMA_TodosDias']))
print("MAPE of ARIMA_TodosDias:", mean_absolute_percentage_error(dataPrueba3inv['REAL'],dataPrueba3inv['ARIMA_TodosDias']))
print("R2 of ARIMA_TodosDias:", r2_score(dataPrueba3inv['REAL'],dataPrueba3inv['ARIMA_TodosDias']))
# Out:
# MSE of ARIMA_TodosDias: 22214.059018466014
# RMSE of ARIMA_TodosDias: 149.0438157672636
# MAE of ARIMA_TodosDias: 145.77576008333332
# MAPE of ARIMA_TodosDias: 0.1264115735872086
# R2 of ARIMA_TodosDias: 0.2843940294010815

# %%
# Evaluacion de la prediccion de CNDC
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of PROPHET_Lunes:", mean_squared_error(dataPrueba3inv['REAL'],dataPrueba3inv['CNDC_Predic']))
print("RMSE of PROPHET_Lunes:", np.sqrt(mean_squared_error(dataPrueba3inv['REAL'],dataPrueba3inv['CNDC_Predic'])))
print("MAE of PROPHET_Lunest:", mean_absolute_error(dataPrueba3inv['REAL'],dataPrueba3inv['CNDC_Predic']))
print("MAPE of PROPHET_Lunes:", mean_absolute_percentage_error(dataPrueba3inv['REAL'],dataPrueba3inv['CNDC_Predic']))
print("R2 of PROPHET_Lunes:", r2_score(dataPrueba3inv['REAL'],dataPrueba3inv['CNDC_Predic']))
# Out:
# MSE of PROPHET_Lunes: 5451.052600124998
# RMSE of PROPHET_Lunes: 73.83124406458961
# MAE of PROPHET_Lunest: 60.98845833333334
# MAPE of PROPHET_Lunes: 0.050012055495134496
# R2 of PROPHET_Lunes: 0.8243992336809962

# %%
# exportar a csv
#dataPrueba3inv.to_csv('03enero2023.csv')# exportar a csv

# %% [markdown]
# # 04 de enero de 2023

# %%
dataPrueba4 = pd.read_csv('04 de enero 2023.csv')

# %%
dataPrueba4.head()
# Out:
#           04/01/2023           H1           H2           H3           H4  \
# 0               REAL  1014.670000   977.700000   951.170000   937.720000
# 1  PROPHET_Miercoles  1066.740201  1009.452528   977.841444   962.316112
# 2    ARIMA_Miercoles  1120.626695  1063.410602  1027.638053  1009.899355
# 3  PROPHET_TodosDias  1110.987567  1122.397271  1028.537505  1067.061558
# 4    ARIMA_TodosDias  1151.654154  1092.155099  1042.927787  1022.363163
#
#             H5           H6           H7           H8           H9  ...  \
# 0   962.600000   947.820000   998.107000  1109.557000  1186.861000  ...
# 1   967.835114   922.627224   968.211448  1071.429607  1170.087368  ...
# 2  1025.345110  1013.865939  1088.536653  1188.081873  1309.354357  ...
# 3  1026.497862   965.336075  1099.542271  1100.325981  1266.529519  ...
# 4  1036.013729   979.858319  1070.796814  1215.003628  1351.511105  ...
#
#            H17          H18          H19          H20          H21  \
# ...

# %%
dataPrueba04 = dataPrueba4.set_index('04/01/2023')
dataPrueba04
# Out:
#                             H1           H2           H3           H4  \
# 04/01/2023
# REAL               1014.670000   977.700000   951.170000   937.720000
# PROPHET_Miercoles  1066.740201  1009.452528   977.841444   962.316112
# ARIMA_Miercoles    1120.626695  1063.410602  1027.638053  1009.899355
# PROPHET_TodosDias  1110.987567  1122.397271  1028.537505  1067.061558
# ARIMA_TodosDias    1151.654154  1092.155099  1042.927787  1022.363163
# CNDC_Predic        1043.210000   999.930000   967.860000   934.580000
#
#                             H5           H6           H7           H8  \
# 04/01/2023
# REAL                962.600000   947.820000   998.107000  1109.557000
# PROPHET_Miercoles   967.835114   922.627224   968.211448  1071.429607
# ARIMA_Miercoles    1025.345110  1013.865939  1088.536653  1188.081873
# PROPHET_TodosDias  1026.497862   965.336075  1099.542271  1100.325981
# ARIMA_TodosDias    1036.013729   979.858319  1070.796814  1215.003628
# ...

# %%
dataPrueba_4 = dataPrueba04.drop(columns=["TOTAL","DEMANDA MAXIMA"])

# %%
# invertir columnas y filas
dataPrueba4inv = dataPrueba_4.transpose()
dataPrueba4inv
# Out:
# 04/01/2023      REAL  PROPHET_Miercoles  ARIMA_Miercoles  PROPHET_TodosDias  \
# H1          1014.670        1066.740201      1120.626695        1110.987567
# H2           977.700        1009.452528      1063.410602        1122.397271
# H3           951.170         977.841444      1027.638053        1028.537505
# H4           937.720         962.316112      1009.899355        1067.061558
# H5           962.600         967.835114      1025.345110        1026.497862
# H6           947.820         922.627224      1013.865939         965.336075
# H7           998.107         968.211448      1088.536653        1099.542271
# H8          1109.557        1071.429607      1188.081873        1100.325981
# H9          1186.861        1170.087368      1309.354357        1266.529519
# H10         1234.751        1238.031956      1383.549629        1344.448361
# H11         1253.756        1275.666346      1416.187287        1385.369002
# ...

# %%
# Evaluacion del modelo PROPHET que predijo usando dias especifico MIERCOLES
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of PROPHET_Lunes:", mean_squared_error(dataPrueba4inv['REAL'],dataPrueba4inv['PROPHET_Miercoles']))
print("RMSE of PROPHET_Lunes:", np.sqrt(mean_squared_error(dataPrueba4inv['REAL'],dataPrueba4inv['PROPHET_Miercoles'])))
print("MAE of PROPHET_Lunest:", mean_absolute_error(dataPrueba4inv['REAL'],dataPrueba4inv['PROPHET_Miercoles']))
print("MAPE of PROPHET_Lunes:", mean_absolute_percentage_error(dataPrueba4inv['REAL'],dataPrueba4inv['PROPHET_Miercoles']))
print("R2 of PROPHET_Lunes:", r2_score(dataPrueba4inv['REAL'],dataPrueba4inv['PROPHET_Miercoles']))
# Out:
# MSE of PROPHET_Lunes: 1852.5004056815076
# RMSE of PROPHET_Lunes: 43.040683146082934
# MAE of PROPHET_Lunest: 38.02341774999999
# MAPE of PROPHET_Lunes: 0.03293055767363021
# R2 of PROPHET_Lunes: 0.9041072594707853

# %%
# Evaluacion del modelo ARIMA que predijo usando dias especifico MIERCOLES
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of ARIMA_Lunes:", mean_squared_error(dataPrueba4inv['REAL'],dataPrueba4inv['ARIMA_Miercoles']))
print("RMSE of ARIMA_Lunes:", np.sqrt(mean_squared_error(dataPrueba4inv['REAL'],dataPrueba4inv['ARIMA_Miercoles'])))
print("MAE of ARIMA_Lunes:", mean_absolute_error(dataPrueba4inv['REAL'],dataPrueba4inv['ARIMA_Miercoles']))
print("MAPE of ARIMA_Lunes:", mean_absolute_percentage_error(dataPrueba4inv['REAL'],dataPrueba4inv['ARIMA_Miercoles']))
print("R2 of ARIMA_Lunes:", r2_score(dataPrueba4inv['REAL'],dataPrueba4inv['ARIMA_Miercoles']))
# Out:
# MSE of ARIMA_Lunes: 24495.67664261368
# RMSE of ARIMA_Lunes: 156.5109473570896
# MAE of ARIMA_Lunes: 145.79388270833329
# MAPE of ARIMA_Lunes: 0.1233328218086091
# R2 of ARIMA_Lunes: -0.26799300943394555

# %%
# Evaluacion del modelo PROPHET que predijo usando todos los dias
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of PROPHET_TodosDias:", mean_squared_error(dataPrueba4inv['REAL'],dataPrueba4inv['PROPHET_TodosDias']))
print("RMSE of PROPHET_TodosDias:", np.sqrt(mean_squared_error(dataPrueba4inv['REAL'],dataPrueba4inv['PROPHET_TodosDias'])))
print("MAE of PROPHET_TodosDias:", mean_absolute_error(dataPrueba4inv['REAL'],dataPrueba4inv['PROPHET_TodosDias']))
print("MAPE of PROPHET_TodosDias:", mean_absolute_percentage_error(dataPrueba4inv['REAL'],dataPrueba4inv['PROPHET_TodosDias']))
print("R2 of PROPHET_TodosDias:", r2_score(dataPrueba4inv['REAL'],dataPrueba4inv['PROPHET_TodosDias']))
# Out:
# MSE of PROPHET_TodosDias: 18567.272169362328
# RMSE of PROPHET_TodosDias: 136.26177809408745
# MAE of PROPHET_TodosDias: 127.13463145833332
# MAPE of PROPHET_TodosDias: 0.1087952726347788
# R2 of PROPHET_TodosDias: 0.03888463019420274

# %%
# Evaluacion del modelo ARIMA que predijo usando todos los dias
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of ARIMA_TodosDias:", mean_squared_error(dataPrueba4inv['REAL'],dataPrueba4inv['ARIMA_TodosDias']))
print("RMSE of ARIMA_TodosDias:", np.sqrt(mean_squared_error(dataPrueba4inv['REAL'],dataPrueba4inv['ARIMA_TodosDias'])))
print("MAE of ARIMA_TodosDias:", mean_absolute_error(dataPrueba4inv['REAL'],dataPrueba4inv['ARIMA_TodosDias']))
print("MAPE of ARIMA_TodosDias:", mean_absolute_percentage_error(dataPrueba4inv['REAL'],dataPrueba4inv['ARIMA_TodosDias']))
print("R2 of ARIMA_TodosDias:", r2_score(dataPrueba4inv['REAL'],dataPrueba4inv['ARIMA_TodosDias']))
# Out:
# MSE of ARIMA_TodosDias: 31250.313297741068
# RMSE of ARIMA_TodosDias: 176.77758143424484
# MAE of ARIMA_TodosDias: 165.064625125
# MAPE of ARIMA_TodosDias: 0.1397610821799619
# R2 of ARIMA_TodosDias: -0.6176396913740592

# %%
# Evaluacion de la prediccion del CNDC
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of PROPHET_Lunes:", mean_squared_error(dataPrueba4inv['REAL'],dataPrueba4inv['CNDC_Predic']))
print("RMSE of PROPHET_Lunes:", np.sqrt(mean_squared_error(dataPrueba4inv['REAL'],dataPrueba4inv['CNDC_Predic'])))
print("MAE of PROPHET_Lunest:", mean_absolute_error(dataPrueba4inv['REAL'],dataPrueba4inv['CNDC_Predic']))
print("MAPE of PROPHET_Lunes:", mean_absolute_percentage_error(dataPrueba4inv['REAL'],dataPrueba4inv['CNDC_Predic']))
print("R2 of PROPHET_Lunes:", r2_score(dataPrueba4inv['REAL'],dataPrueba4inv['CNDC_Predic']))
# Out:
# MSE of PROPHET_Lunes: 4965.746555458329
# RMSE of PROPHET_Lunes: 70.46805343883375
# MAE of PROPHET_Lunest: 57.18762499999996
# MAPE of PROPHET_Lunes: 0.04784076291812394
# R2 of PROPHET_Lunes: 0.7429533378152064

# %%
# exportar a csv
#dataPrueba4inv.to_csv('04enero2023.csv')# exportar a csv

# %% [markdown]
# # 05 de enero de 2023

# %%
dataPrueba5 = pd.read_csv('05 de enero 2023.csv')

# %%
dataPrueba5.head()
# Out:
#           05/01/2023           H1           H2           H3           H4  \
# 0               REAL   974.350000   933.610000   912.770000   903.630000
# 1     PROPHET_Jueves  1047.397104  1005.191324   972.517721   958.230800
# 2       ARIMA_Jueves  1113.093720  1054.291109  1041.356821  1002.787579
# 3  PROPHET_TodosDias  1122.397271  1070.075215  1036.282511  1073.438933
# 4    ARIMA_TodosDias  1141.278984  1081.506002  1041.372355  1028.242587
#
#             H5          H6           H7           H8           H9  ...  \
# 0   929.080000  897.525000   990.292000  1087.694000  1224.261000  ...
# 1   974.412502  947.170339  1009.154936  1119.781537  1238.242449  ...
# 2  1013.344146  979.535478  1076.620502  1195.864925  1321.845552  ...
# 3  1032.960809  969.378391  1095.275319  1095.494401  1290.719665  ...
# 4  1046.306983  990.935965  1066.857519  1212.987487  1354.174357  ...
#
#            H17          H18          H19          H20          H21  \
# ...

# %%
dataPrueba05 = dataPrueba5.set_index('05/01/2023')
dataPrueba05
# Out:
#                             H1           H2           H3           H4  \
# 05/01/2023
# REAL                974.350000   933.610000   912.770000   903.630000
# PROPHET_Jueves     1047.397104  1005.191324   972.517721   958.230800
# ARIMA_Jueves       1113.093720  1054.291109  1041.356821  1002.787579
# PROPHET_TodosDias  1122.397271  1070.075215  1036.282511  1073.438933
# ARIMA_TodosDias    1141.278984  1081.506002  1041.372355  1028.242587
# CNDC_Predic        1028.900000   973.470000   938.040000   915.870000
#
#                             H5          H6           H7           H8  \
# 05/01/2023
# REAL                929.080000  897.525000   990.292000  1087.694000
# PROPHET_Jueves      974.412502  947.170339  1009.154936  1119.781537
# ARIMA_Jueves       1013.344146  979.535478  1076.620502  1195.864925
# PROPHET_TodosDias  1032.960809  969.378391  1095.275319  1095.494401
# ARIMA_TodosDias    1046.306983  990.935965  1066.857519  1212.987487
# ...

# %%
dataPrueba_5 = dataPrueba05.drop(columns=["TOTAL","DEMANDA MAXIMA"])

# %%
# invertir columnas y filas
dataPrueba5inv = dataPrueba_5.transpose()
dataPrueba5inv
# Out:
# 05/01/2023      REAL  PROPHET_Jueves  ARIMA_Jueves  PROPHET_TodosDias  \
# H1           974.350     1047.397104   1113.093720        1122.397271
# H2           933.610     1005.191324   1054.291109        1070.075215
# H3           912.770      972.517721   1041.356821        1036.282511
# H4           903.630      958.230800   1002.787579        1073.438933
# H5           929.080      974.412502   1013.344146        1032.960809
# H6           897.525      947.170339    979.535478         969.378391
# H7           990.292     1009.154936   1076.620502        1095.275319
# H8          1087.694     1119.781537   1195.864925        1095.494401
# H9          1224.261     1238.242449   1321.845552        1290.719665
# H10         1292.559     1292.011882   1350.426093        1345.377781
# H11         1320.306     1322.658758   1407.945215        1373.585178
# H12         1355.509     1312.955930   1393.948493        1393.674697
# ...

# %%
# Evaluacion del modelo PROPHET que predijo usando dias especifico JUEVES
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of PROPHET_Lunes:", mean_squared_error(dataPrueba5inv['REAL'],dataPrueba5inv['PROPHET_Jueves']))
print("RMSE of PROPHET_Lunes:", np.sqrt(mean_squared_error(dataPrueba5inv['REAL'],dataPrueba5inv['PROPHET_Jueves'])))
print("MAE of PROPHET_Lunest:", mean_absolute_error(dataPrueba5inv['REAL'],dataPrueba5inv['PROPHET_Jueves']))
print("MAPE of PROPHET_Lunes:", mean_absolute_percentage_error(dataPrueba5inv['REAL'],dataPrueba5inv['PROPHET_Jueves']))
print("R2 of PROPHET_Lunes:", r2_score(dataPrueba5inv['REAL'],dataPrueba5inv['PROPHET_Jueves']))
# Out:
# MSE of PROPHET_Lunes: 3492.2213635905887
# RMSE of PROPHET_Lunes: 59.09501978670105
# MAE of PROPHET_Lunest: 50.03303820833337
# MAPE of PROPHET_Lunes: 0.04178739576973169
# R2 of PROPHET_Lunes: 0.9182011031037017

# %%
# Evaluacion del modelo ARIMA que predijo usando dias especifico JUEVES
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of ARIMA_Lunes:", mean_squared_error(dataPrueba5inv['REAL'],dataPrueba5inv['ARIMA_Jueves']))
print("RMSE of ARIMA_Lunes:", np.sqrt(mean_squared_error(dataPrueba5inv['REAL'],dataPrueba5inv['ARIMA_Jueves'])))
print("MAE of ARIMA_Lunes:", mean_absolute_error(dataPrueba5inv['REAL'],dataPrueba5inv['ARIMA_Jueves']))
print("MAPE of ARIMA_Lunes:", mean_absolute_percentage_error(dataPrueba5inv['REAL'],dataPrueba5inv['ARIMA_Jueves']))
print("R2 of ARIMA_Lunes:", r2_score(dataPrueba5inv['REAL'],dataPrueba5inv['ARIMA_Jueves']))
# Out:
# MSE of ARIMA_Lunes: 5876.391932955726
# RMSE of ARIMA_Lunes: 76.65762801545405
# MAE of ARIMA_Lunes: 67.29901595833333
# MAPE of ARIMA_Lunes: 0.061261079597804045
# R2 of ARIMA_Lunes: 0.8623562690333403

# %%
# Evaluacion del modelo PROPHET que predijo usando todos los dias
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of PROPHET_TodosDias:", mean_squared_error(dataPrueba5inv['REAL'],dataPrueba5inv['PROPHET_TodosDias']))
print("RMSE of PROPHET_TodosDias:", np.sqrt(mean_squared_error(dataPrueba5inv['REAL'],dataPrueba5inv['PROPHET_TodosDias'])))
print("MAE of PROPHET_TodosDias:", mean_absolute_error(dataPrueba5inv['REAL'],dataPrueba5inv['PROPHET_TodosDias']))
print("MAPE of PROPHET_TodosDias:", mean_absolute_percentage_error(dataPrueba5inv['REAL'],dataPrueba5inv['PROPHET_TodosDias']))
print("R2 of PROPHET_TodosDias:", r2_score(dataPrueba5inv['REAL'],dataPrueba5inv['PROPHET_TodosDias']))
# Out:
# MSE of PROPHET_TodosDias: 5705.5205850194225
# RMSE of PROPHET_TodosDias: 75.53489647189187
# MAE of PROPHET_TodosDias: 58.860395833333335
# MAPE of PROPHET_TodosDias: 0.05598940359428339
# R2 of PROPHET_TodosDias: 0.8663586177727691

# %%
# Evaluacion del modelo ARIMA que predijo usando todos los dias
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of ARIMA_TodosDias:", mean_squared_error(dataPrueba5inv['REAL'],dataPrueba5inv['ARIMA_TodosDias']))
print("RMSE of ARIMA_TodosDias:", np.sqrt(mean_squared_error(dataPrueba5inv['REAL'],dataPrueba5inv['ARIMA_TodosDias'])))
print("MAE of ARIMA_TodosDias:", mean_absolute_error(dataPrueba5inv['REAL'],dataPrueba5inv['ARIMA_TodosDias']))
print("MAPE of ARIMA_TodosDias:", mean_absolute_percentage_error(dataPrueba5inv['REAL'],dataPrueba5inv['ARIMA_TodosDias']))
print("R2 of ARIMA_TodosDias:", r2_score(dataPrueba5inv['REAL'],dataPrueba5inv['ARIMA_TodosDias']))
# Out:
# MSE of ARIMA_TodosDias: 11828.019154414453
# RMSE of ARIMA_TodosDias: 108.7566970554662
# MAE of ARIMA_TodosDias: 104.9154014583333
# MAPE of ARIMA_TodosDias: 0.09108050153763088
# R2 of ARIMA_TodosDias: 0.7229502890662642

# %%
# Evaluacion de la prediccion del CNDC
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of PROPHET_Lunes:", mean_squared_error(dataPrueba5inv['REAL'],dataPrueba5inv['CNDC_Predic']))
print("RMSE of PROPHET_Lunes:", np.sqrt(mean_squared_error(dataPrueba5inv['REAL'],dataPrueba5inv['CNDC_Predic'])))
print("MAE of PROPHET_Lunest:", mean_absolute_error(dataPrueba5inv['REAL'],dataPrueba5inv['CNDC_Predic']))
print("MAPE of PROPHET_Lunes:", mean_absolute_percentage_error(dataPrueba5inv['REAL'],dataPrueba5inv['CNDC_Predic']))
print("R2 of PROPHET_Lunes:", r2_score(dataPrueba5inv['REAL'],dataPrueba5inv['CNDC_Predic']))
# Out:
# MSE of PROPHET_Lunes: 3666.8732568333385
# RMSE of PROPHET_Lunes: 60.554712920080284
# MAE of PROPHET_Lunest: 49.281000000000034
# MAPE of PROPHET_Lunes: 0.04059637719275879
# R2 of PROPHET_Lunes: 0.9141102020064648

# %%
# exportar a csv
#dataPrueba5inv.to_csv('05enero2023.csv')# exportar a csv

# %% [markdown]
# # 06 de enero de 2023

# %%
dataPrueba6 = pd.read_csv('06 de enero 2023.csv')

# %%
dataPrueba6.head()
# Out:
#           06/01/2023           H1           H2           H3           H4  \
# 0               REAL  1057.490000   998.010000   971.910000   957.730000
# 1    PROPHET_Viernes  1056.698732  1003.761491   971.888454   957.908173
# 2      ARIMA_Viernes  1113.093720  1054.291109  1041.356821  1002.787579
# 3  PROPHET_TodosDias  1119.190596  1065.953175  1032.091426  1071.128240
# 4    ARIMA_TodosDias  1164.305580  1100.548401  1060.103384  1036.958139
#
#             H5          H6           H7           H8           H9  ...  \
# 0   979.340000  953.640000  1042.190000  1163.468000  1291.834000  ...
# 1   971.369534  924.885114   964.042106  1058.176910  1164.167063  ...
# 2  1013.344146  979.535478  1076.620502  1195.864925  1321.845552  ...
# 3  1026.392778  965.386661  1093.984756  1090.989755  1279.961566  ...
# 4  1042.673009  957.337035  1024.389117  1141.209023  1254.484041  ...
#
#            H17          H18          H19          H20          H21  \
# ...

# %%
dataPrueba06 = dataPrueba6.set_index('06/01/2023')
dataPrueba06
# Out:
#                             H1           H2           H3           H4  \
# 06/01/2023
# REAL               1057.490000   998.010000   971.910000   957.730000
# PROPHET_Viernes    1056.698732  1003.761491   971.888454   957.908173
# ARIMA_Viernes      1113.093720  1054.291109  1041.356821  1002.787579
# PROPHET_TodosDias  1119.190596  1065.953175  1032.091426  1071.128240
# ARIMA_TodosDias    1164.305580  1100.548401  1060.103384  1036.958139
# CNDC_Predic        1041.630000   991.230000   958.530000   937.360000
#
#                             H5          H6           H7           H8  \
# 06/01/2023
# REAL                979.340000  953.640000  1042.190000  1163.468000
# PROPHET_Viernes     971.369534  924.885114   964.042106  1058.176910
# ARIMA_Viernes      1013.344146  979.535478  1076.620502  1195.864925
# PROPHET_TodosDias  1026.392778  965.386661  1093.984756  1090.989755
# ARIMA_TodosDias    1042.673009  957.337035  1024.389117  1141.209023
# ...

# %%
dataPrueba_6 = dataPrueba06.drop(columns=["TOTAL","DEMANDA MAXIMA"])

# %%
# invertir columnas y filas
dataPrueba6inv = dataPrueba_6.transpose()
dataPrueba6inv
# Out:
# 06/01/2023      REAL  PROPHET_Viernes  ARIMA_Viernes  PROPHET_TodosDias  \
# H1          1057.490      1056.698732    1113.093720        1119.190596
# H2           998.010      1003.761491    1054.291109        1065.953175
# H3           971.910       971.888454    1041.356821        1032.091426
# H4           957.730       957.908173    1002.787579        1071.128240
# H5           979.340       971.369534    1013.344146        1026.392778
# H6           953.640       924.885114     979.535478         965.386661
# H7          1042.190       964.042106    1076.620502        1093.984756
# H8          1163.468      1058.176910    1195.864925        1090.989755
# H9          1291.834      1164.167063    1321.845552        1279.961566
# H10         1365.882      1224.993562    1350.426093        1332.813342
# H11         1400.245      1249.802425    1407.945215        1371.765048
# H12         1424.374      1262.968955    1412.792214        1368.183005
# ...

# %%
# Evaluacion del modelo PROPHET que predijo usando dias especifico VIERNES
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of PROPHET_Lunes:", mean_squared_error(dataPrueba6inv['REAL'],dataPrueba6inv['PROPHET_Viernes']))
print("RMSE of PROPHET_Lunes:", np.sqrt(mean_squared_error(dataPrueba6inv['REAL'],dataPrueba6inv['PROPHET_Viernes'])))
print("MAE of PROPHET_Lunest:", mean_absolute_error(dataPrueba6inv['REAL'],dataPrueba6inv['PROPHET_Viernes']))
print("MAPE of PROPHET_Lunes:", mean_absolute_percentage_error(dataPrueba6inv['REAL'],dataPrueba6inv['PROPHET_Viernes']))
print("R2 of PROPHET_Lunes:", r2_score(dataPrueba6inv['REAL'],dataPrueba6inv['PROPHET_Viernes']))
# Out:
# MSE of PROPHET_Lunes: 17092.87386795227
# RMSE of PROPHET_Lunes: 130.73971802001208
# MAE of PROPHET_Lunest: 105.86961445833333
# MAPE of PROPHET_Lunes: 0.07638814699926129
# R2 of PROPHET_Lunes: 0.5987765023181084

# %%
# Evaluacion del modelo ARIMA que predijo usando dias especifico VIERNES
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of ARIMA_Lunes:", mean_squared_error(dataPrueba6inv['REAL'],dataPrueba6inv['ARIMA_Viernes']))
print("RMSE of ARIMA_Lunes:", np.sqrt(mean_squared_error(dataPrueba6inv['REAL'],dataPrueba6inv['ARIMA_Viernes'])))
print("MAE of ARIMA_Lunes:", mean_absolute_error(dataPrueba6inv['REAL'],dataPrueba6inv['ARIMA_Viernes']))
print("MAPE of ARIMA_Lunes:", mean_absolute_percentage_error(dataPrueba6inv['REAL'],dataPrueba6inv['ARIMA_Viernes']))
print("R2 of ARIMA_Lunes:", r2_score(dataPrueba6inv['REAL'],dataPrueba6inv['ARIMA_Viernes']))
# Out:
# MSE of ARIMA_Lunes: 1869.5717016778492
# RMSE of ARIMA_Lunes: 43.238544166956515
# MAE of ARIMA_Lunes: 34.411036333333335
# MAPE of ARIMA_Lunes: 0.028426364345190247
# R2 of ARIMA_Lunes: 0.956115273352559

# %%
# Evaluacion del modelo PROPHET que predijo usando todos los dias
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of PROPHET_TodosDias:", mean_squared_error(dataPrueba6inv['REAL'],dataPrueba6inv['PROPHET_TodosDias']))
print("RMSE of PROPHET_TodosDias:", np.sqrt(mean_squared_error(dataPrueba6inv['REAL'],dataPrueba6inv['PROPHET_TodosDias'])))
print("MAE of PROPHET_TodosDias:", mean_absolute_error(dataPrueba6inv['REAL'],dataPrueba6inv['PROPHET_TodosDias']))
print("MAPE of PROPHET_TodosDias:", mean_absolute_percentage_error(dataPrueba6inv['REAL'],dataPrueba6inv['PROPHET_TodosDias']))
print("R2 of PROPHET_TodosDias:", r2_score(dataPrueba6inv['REAL'],dataPrueba6inv['PROPHET_TodosDias']))
# Out:
# MSE of PROPHET_TodosDias: 3860.53626925438
# RMSE of PROPHET_TodosDias: 62.13321389767618
# MAE of PROPHET_TodosDias: 54.729312375000006
# MAPE of PROPHET_TodosDias: 0.04385816046135745
# R2 of PROPHET_TodosDias: 0.9093810744264501

# %%
# Evaluacion del modelo ARIMA que predijo usando todos los dias
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of ARIMA_TodosDias:", mean_squared_error(dataPrueba6inv['REAL'],dataPrueba6inv['ARIMA_TodosDias']))
print("RMSE of ARIMA_TodosDias:", np.sqrt(mean_squared_error(dataPrueba6inv['REAL'],dataPrueba6inv['ARIMA_TodosDias'])))
print("MAE of ARIMA_TodosDias:", mean_absolute_error(dataPrueba6inv['REAL'],dataPrueba6inv['ARIMA_TodosDias']))
print("MAPE of ARIMA_TodosDias:", mean_absolute_percentage_error(dataPrueba6inv['REAL'],dataPrueba6inv['ARIMA_TodosDias']))
print("R2 of ARIMA_TodosDias:", r2_score(dataPrueba6inv['REAL'],dataPrueba6inv['ARIMA_TodosDias']))
# Out:
# MSE of ARIMA_TodosDias: 6863.541710470015
# RMSE of ARIMA_TodosDias: 82.84649485928789
# MAE of ARIMA_TodosDias: 67.89158308333333
# MAPE of ARIMA_TodosDias: 0.0530693725403506
# R2 of ARIMA_TodosDias: 0.8388910938655256

# %%
# Evaluacion de la prediccion del CNDC
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of PROPHET_Lunes:", mean_squared_error(dataPrueba6inv['REAL'],dataPrueba6inv['CNDC_Predic']))
print("RMSE of PROPHET_Lunes:", np.sqrt(mean_squared_error(dataPrueba6inv['REAL'],dataPrueba6inv['CNDC_Predic'])))
print("MAE of PROPHET_Lunest:", mean_absolute_error(dataPrueba6inv['REAL'],dataPrueba6inv['CNDC_Predic']))
print("MAPE of PROPHET_Lunes:", mean_absolute_percentage_error(dataPrueba6inv['REAL'],dataPrueba6inv['CNDC_Predic']))
print("R2 of PROPHET_Lunes:", r2_score(dataPrueba6inv['REAL'],dataPrueba6inv['CNDC_Predic']))
# Out:
# MSE of PROPHET_Lunes: 2819.1069056249967
# RMSE of PROPHET_Lunes: 53.09526255349903
# MAE of PROPHET_Lunest: 41.79354166666665
# MAPE of PROPHET_Lunes: 0.030555840510853267
# R2 of PROPHET_Lunes: 0.9338266963325144

# %%
# exportar a csv
#dataPrueba6inv.to_csv('06enero2023.csv')# exportar a csv

# %% [markdown]
# # 07 de enero de 2023

# %%
dataPrueba7 = pd.read_csv('07 de enero 2023.csv')

# %%
dataPrueba7.head()
# Out:
#           07/01/2023           H1           H2           H3           H4  \
# 0               REAL  1136.550000  1072.030000  1039.660000  1010.900000
# 1     PROPHET_Sabado  1058.211448  1000.510423   969.078795   950.777033
# 2       ARIMA_Sabado  1124.919889  1079.806230  1037.747329  1008.163403
# 3  PROPHET_TodosDias  1120.211184  1070.289113  1030.343744  1064.348723
# 4    ARIMA_TodosDias  1125.319576  1066.075174  1018.872814   979.579753
#
#             H5          H6          H7           H8           H9  ...  \
# 0  1018.060000  972.210000  997.739000  1112.479000  1223.756000  ...
# 1   950.944046  885.658921  884.129930   975.253526  1063.502467  ...
# 2  1009.969519  976.432751  992.237173  1070.806841  1168.519512  ...
# 3  1019.832758  929.901931  995.581965   980.571240  1180.191604  ...
# 4   974.135577  866.357142  883.113815   967.172032  1039.416423  ...
#
#            H17          H18          H19          H20          H21  \
# ...

# %%
dataPrueba07 = dataPrueba7.set_index('07/01/2023')
dataPrueba07
# Out:
#                             H1           H2           H3           H4  \
# 07/01/2023
# REAL               1136.550000  1072.030000  1039.660000  1010.900000
# PROPHET_Sabado     1058.211448  1000.510423   969.078795   950.777033
# ARIMA_Sabado       1124.919889  1079.806230  1037.747329  1008.163403
# PROPHET_TodosDias  1120.211184  1070.289113  1030.343744  1064.348723
# ARIMA_TodosDias    1125.319576  1066.075174  1018.872814   979.579753
# CNDC_Predic        1123.460000  1061.160000  1039.670000  1005.830000
#
#                             H5          H6           H7           H8  \
# 07/01/2023
# REAL               1018.060000  972.210000   997.739000  1112.479000
# PROPHET_Sabado      950.944046  885.658921   884.129930   975.253526
# ARIMA_Sabado       1009.969519  976.432751   992.237173  1070.806841
# PROPHET_TodosDias  1019.832758  929.901931   995.581965   980.571240
# ARIMA_TodosDias     974.135577  866.357142   883.113815   967.172032
# ...

# %%
dataPrueba_7 = dataPrueba07.drop(columns=["TOTAL","DEMANDA MAXIMA"])

# %%
# invertir columnas y filas
dataPrueba7inv = dataPrueba_7.transpose()
dataPrueba7inv
# Out:
# 07/01/2023      REAL  PROPHET_Sabado  ARIMA_Sabado  PROPHET_TodosDias  \
# H1          1136.550     1058.211448   1124.919889        1120.211184
# H2          1072.030     1000.510423   1079.806230        1070.289113
# H3          1039.660      969.078795   1037.747329        1030.343744
# H4          1010.900      950.777033   1008.163403        1064.348723
# H5          1018.060      950.944046   1009.969519        1019.832758
# H6           972.210      885.658921    976.432751         929.901931
# H7           997.739      884.129930    992.237173         995.581965
# H8          1112.479      975.253526   1070.806841         980.571240
# H9          1223.756     1063.502467   1168.519512        1180.191604
# H10         1319.358     1107.928226   1230.131720        1238.252069
# H11         1383.259     1134.647716   1270.680866        1268.088115
# H12         1380.764     1150.651496   1256.504478        1275.695516
# ...

# %%
# Evaluacion del modelo PROPHET que predijo usando dias especifico SABADO
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of PROPHET_Lunes:", mean_squared_error(dataPrueba7inv['REAL'],dataPrueba7inv['PROPHET_Sabado']))
print("RMSE of PROPHET_Lunes:", np.sqrt(mean_squared_error(dataPrueba7inv['REAL'],dataPrueba7inv['PROPHET_Sabado'])))
print("MAE of PROPHET_Lunest:", mean_absolute_error(dataPrueba7inv['REAL'],dataPrueba7inv['PROPHET_Sabado']))
print("MAPE of PROPHET_Lunes:", mean_absolute_percentage_error(dataPrueba7inv['REAL'],dataPrueba7inv['PROPHET_Sabado']))
print("R2 of PROPHET_Lunes:", r2_score(dataPrueba7inv['REAL'],dataPrueba7inv['PROPHET_Sabado']))
# Out:
# MSE of PROPHET_Lunes: 33505.084017123656
# RMSE of PROPHET_Lunes: 183.04394012674567
# MAE of PROPHET_Lunest: 168.8825506666667
# MAPE of PROPHET_Lunes: 0.12983466408099695
# R2 of PROPHET_Lunes: -0.1611030584544666

# %%
# Evaluacion del modelo ARIMA que predijo usando dias especifico SABADO
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of ARIMA_Lunes:", mean_squared_error(dataPrueba7inv['REAL'],dataPrueba7inv['ARIMA_Sabado']))
print("RMSE of ARIMA_Lunes:", np.sqrt(mean_squared_error(dataPrueba7inv['REAL'],dataPrueba7inv['ARIMA_Sabado'])))
print("MAE of ARIMA_Lunes:", mean_absolute_error(dataPrueba7inv['REAL'],dataPrueba7inv['ARIMA_Sabado']))
print("MAPE of ARIMA_Lunes:", mean_absolute_percentage_error(dataPrueba7inv['REAL'],dataPrueba7inv['ARIMA_Sabado']))
print("R2 of ARIMA_Lunes:", r2_score(dataPrueba7inv['REAL'],dataPrueba7inv['ARIMA_Sabado']))
# Out:
# MSE of ARIMA_Lunes: 8675.445838543315
# RMSE of ARIMA_Lunes: 93.1420734069374
# MAE of ARIMA_Lunes: 75.8274285
# MAPE of ARIMA_Lunes: 0.056016958374499916
# R2 of ARIMA_Lunes: 0.6993564710525543

# %%
# Evaluacion del modelo PROPHET que predijo usando todos los dias
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of PROPHET_TodosDias:", mean_squared_error(dataPrueba7inv['REAL'],dataPrueba7inv['PROPHET_TodosDias']))
print("RMSE of PROPHET_TodosDias:", np.sqrt(mean_squared_error(dataPrueba7inv['REAL'],dataPrueba7inv['PROPHET_TodosDias'])))
print("MAE of PROPHET_TodosDias:", mean_absolute_error(dataPrueba7inv['REAL'],dataPrueba7inv['PROPHET_TodosDias']))
print("MAPE of PROPHET_TodosDias:", mean_absolute_percentage_error(dataPrueba7inv['REAL'],dataPrueba7inv['PROPHET_TodosDias']))
print("R2 of PROPHET_TodosDias:", r2_score(dataPrueba7inv['REAL'],dataPrueba7inv['PROPHET_TodosDias']))
# Out:
# MSE of PROPHET_TodosDias: 7556.2086857886125
# RMSE of PROPHET_TodosDias: 86.92645561501178
# MAE of PROPHET_TodosDias: 74.35236766666668
# MAPE of PROPHET_TodosDias: 0.05644201188985958
# R2 of PROPHET_TodosDias: 0.738143112522702

# %%
# Evaluacion del modelo ARIMA que predijo usando todos los dias
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of ARIMA_TodosDias:", mean_squared_error(dataPrueba7inv['REAL'],dataPrueba7inv['ARIMA_TodosDias']))
print("RMSE of ARIMA_TodosDias:", np.sqrt(mean_squared_error(dataPrueba7inv['REAL'],dataPrueba7inv['ARIMA_TodosDias'])))
print("MAE of ARIMA_TodosDias:", mean_absolute_error(dataPrueba7inv['REAL'],dataPrueba7inv['ARIMA_TodosDias']))
print("MAPE of ARIMA_TodosDias:", mean_absolute_percentage_error(dataPrueba7inv['REAL'],dataPrueba7inv['ARIMA_TodosDias']))
print("R2 of ARIMA_TodosDias:", r2_score(dataPrueba7inv['REAL'],dataPrueba7inv['ARIMA_TodosDias']))
# Out:
# MSE of ARIMA_TodosDias: 20814.868984220233
# RMSE of ARIMA_TodosDias: 144.2735907372525
# MAE of ARIMA_TodosDias: 124.00109837500001
# MAPE of ARIMA_TodosDias: 0.09567815061072965
# R2 of ARIMA_TodosDias: 0.2786704242688862

# %%
# Evaluacion de la prediccion del CNDC
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score

print("MSE of PROPHET_Lunes:", mean_squared_error(dataPrueba7inv['REAL'],dataPrueba7inv['CNDC_Predic']))
print("RMSE of PROPHET_Lunes:", np.sqrt(mean_squared_error(dataPrueba7inv['REAL'],dataPrueba7inv['CNDC_Predic'])))
print("MAE of PROPHET_Lunest:", mean_absolute_error(dataPrueba7inv['REAL'],dataPrueba7inv['CNDC_Predic']))
print("MAPE of PROPHET_Lunes:", mean_absolute_percentage_error(dataPrueba7inv['REAL'],dataPrueba7inv['CNDC_Predic']))
print("R2 of PROPHET_Lunes:", r2_score(dataPrueba7inv['REAL'],dataPrueba7inv['CNDC_Predic']))
# Out:
# MSE of PROPHET_Lunes: 1615.2087471249997
# RMSE of PROPHET_Lunes: 40.18965970402088
# MAE of PROPHET_Lunest: 29.212208333333308
# MAPE of PROPHET_Lunes: 0.021949402069685816
# R2 of PROPHET_Lunes: 0.9440256942686441

# %%
# exportar a csv
#dataPrueba7inv.to_csv('07enero2023.csv')# exportar a csv
